# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import statistics as st
from seaborn import FacetGrid




# Load the Diamonds dataset from Seaborn
diamonds_data = sns.load_dataset("diamonds")
diamonds_data.head(5)
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# ## STATISTICS challenge:
#
# # calculate the mean of the price by cut

# %%
mean_price_by_cut = diamonds_data.groupby('cut')['price'].mean()

print(mean_price_by_cut)
# Out:
# cut
# Ideal        3457.541970
# Premium      4584.257704
# Very Good    3981.759891
# Good         3928.864452
# Fair         4358.757764
# Name: price, dtype: float64
# C:\Users\bruger\AppData\Local\Temp\ipykernel_22396\996673814.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_price_by_cut = diamonds_data.groupby('cut')['price'].mean()

# %% [markdown]
# # calculate the standard deviation of the price by cut

# %%
sd_price_by_cut = diamonds_data.groupby('cut')['price'].std()

print(sd_price_by_cut)
# Out:
# cut
# Ideal        3808.401172
# Premium      4349.204961
# Very Good    3935.862161
# Good         3681.589584
# Fair         3560.386612
# Name: price, dtype: float64
# C:\Users\bruger\AppData\Local\Temp\ipykernel_22396\3744942347.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   sd_price_by_cut = diamonds_data.groupby('cut')['price'].std()

# %% [markdown]
# # calculate the median of the price by cut

# %%
median_price_by_cut = diamonds_data.groupby('cut')['price'].median()

print(median_price_by_cut)
# Out:
# cut
# Ideal        1810.0
# Premium      3185.0
# Very Good    2648.0
# Good         3050.5
# Fair         3282.0
# Name: price, dtype: float64
# C:\Users\bruger\AppData\Local\Temp\ipykernel_22396\417911363.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   median_price_by_cut = diamonds_data.groupby('cut')['price'].median()

# %%
# calculate the mode of the price by cut
mode_price_by_cut = diamonds_data.groupby('cut')['price'].apply(lambda x: x.mode().iloc[0])

print(mode_price_by_cut)
# Out:
# cut
# Ideal         828
# Premium       802
# Very Good     552
# Good          544
# Fair         2167
# Name: price, dtype: int64
# C:\Users\bruger\AppData\Local\Temp\ipykernel_22396\4217249568.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mode_price_by_cut = diamonds_data.groupby('cut')['price'].apply(lambda x: x.mode().iloc[0])

# %%
# calculate the variance of the price by cut
variance_price_by_cut = diamonds_data.groupby('cut')['price'].var()

print(variance_price_by_cut)
# Out:
# C:\Users\bruger\AppData\Local\Temp\ipykernel_22396\622016923.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   variance_price_by_cut = diamonds_data.groupby('cut')['price'].var()
# cut
# Ideal        1.450392e+07
# Premium      1.891558e+07
# Very Good    1.549101e+07
# Good         1.355410e+07
# Fair         1.267635e+07
# Name: price, dtype: float64

# %%
# Calculate the 25th and 75th percentiles of the price by cut
percentile_25 = diamonds_data.groupby('cut')['price'].quantile(0.25)
percentile_75 = diamonds_data.groupby('cut')['price'].quantile(0.75)

print("25th percentile:")
print(percentile_25)
print("\n75th percentile:")
print(percentile_75)
# Out:
# C:\Users\bruger\AppData\Local\Temp\ipykernel_22396\2780787454.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   percentile_25 = diamonds_data.groupby('cut')['price'].quantile(0.25)
# 25th percentile:
# cut
# Ideal         878.00
# Premium      1046.00
# Very Good     912.00
# Good         1145.00
# Fair         2050.25
# Name: price, dtype: float64
#
# 75th percentile:
# cut
# Ideal        4678.50
# Premium      6296.00
# Very Good    5372.75
# Good         5028.00
# Fair         5205.50
# Name: price, dtype: float64
# ...

# %%
# Calculate the range of the price by cut
price_range_by_cut = diamonds_data.groupby('cut')['price'].apply(lambda x: x.max() - x.min())

print(price_range_by_cut)
# Out:
# C:\Users\bruger\AppData\Local\Temp\ipykernel_22396\1547410341.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   price_range_by_cut = diamonds_data.groupby('cut')['price'].apply(lambda x: x.max() - x.min())
# cut
# Ideal        18480
# Premium      18497
# Very Good    18482
# Good         18461
# Fair         18237
# Name: price, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='cut', y='price', data=diamonds_data)
plt.title('Boxplot of Diamond Price Vs Cut')
plt.xlabel('Cut')
plt.ylabel('Price')
plt.show()
# Out:
# c:\Users\bruger\miniconda3\envs\myenv\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
#Barplot: Average Diamond Price by Color
plt.figure(figsize=(10, 6))
sns.barplot(x='color', y='price', data=diamonds_data, estimator=np.mean)
plt.title('Average Diamond Price by Color')
plt.xlabel('Color')
plt.ylabel('Average Price')
plt.show()
# Out:
# c:\Users\bruger\miniconda3\envs\myenv\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
diamonds=sns.load_dataset('diamonds')
g=FacetGrid(diamonds,col="cut", hue="cut", col_wrap=3)
g.map(plt.scatter, "carat", "price",alpha=0.7)
g.set_titles("{col_name}")
g.set_axis_labels("Carat","Price")
plt.subplots_adjust(top=0.9)
g.fig.suptitle("Scatterplot with Facets: Scatterplot of Carat vs. Price by Cut")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='carat', y='price', hue='cut', data=diamonds_data, alpha=0.7)
plt.title('Scatterplot of Carat vs. Price by Cut')
plt.xlabel('Carat')
plt.ylabel('Price')
plt.legend(title='Cut')
plt.show()

# %%
cut_counts = diamonds_data['cut'].value_counts()

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(cut_counts, labels=cut_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Diamond Cut')
plt.show()
